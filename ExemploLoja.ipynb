# %% [markdown]
# <a href="https://colab.research.google.com/github/MaineCalabrezi13/InteligenciaArtificial/blob/main/ExemploLoja.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
